# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#windows
cityseries= pd.read_csv('C:\\Pri doc\\priti\\Projects\\Myproject\\Berkely\\My class projects data\\zecon\\City_time_series.csv')
#cityc= pd.read_csv('C:\\Pri doc\\priti\\Projects\\Myproject\\Berkely\\My class projects data\\zecon\\cities_crosswalk.csv')
#neigh= pd.read_csv('C:\\Pri doc\\priti\\Projects\\Myproject\\Berkely\\My class projects data\\zecon\\Neighborhood_time_series.csv')

# %%
cityseries.head()
# Out:
#          Date          RegionName  HomesSoldAsForeclosuresRatio_AllHomes  \
# 0  1996-04-30  abbottstownadamspa                                    NaN
# 1  1996-04-30   aberdeenharfordmd                                    NaN
# 2  1996-04-30    aberdeenmonroems                                    NaN
# 3  1996-04-30     aberdeenmoorenc                                    NaN
# 4  1996-04-30     abilenetaylortx                                    NaN
#
#    InventorySeasonallyAdjusted_AllHomes  InventoryRaw_AllHomes  \
# 0                                   NaN                    NaN
# 1                                   NaN                    NaN
# 2                                   NaN                    NaN
# 3                                   NaN                    NaN
# 4                                   NaN                    NaN
#
#    MedianListingPricePerSqft_1Bedroom  MedianListingPricePerSqft_2Bedroom  \
# ...

# %%
df1 = cityseries[['Date','RegionName','MedianSoldPricePerSqft_AllHomes','MedianRentalPrice_AllHomes']]

# %%
mask1 = df1["Date"] > "2010-01-01"
d2=df1[mask1]
d2
# Out:
#                Date                     RegionName  \
# 2198416  2010-01-31           abbevilleabbevillesc
# 2198417  2010-01-31               abbevillehenryal
# 2198418  2010-01-31           abbevillelafayettems
# 2198419  2010-01-31           abbevillevermilionla
# 2198420  2010-01-31             abbottstownadamspa
# 2198421  2010-01-31              aberdeenbinghamid
# 2198422  2010-01-31                aberdeenbrownoh
# 2198423  2010-01-31                aberdeenbrownsd
# 2198424  2010-01-31         aberdeengrays_harborwa
# 2198425  2010-01-31              aberdeenharfordmd
# 2198426  2010-01-31               aberdeenmonroems
# 2198427  2010-01-31                aberdeenmoorenc
# 2198428  2010-01-31                abernathyhaletx
# 2198429  2010-01-31             abilenedickinsonks
# 2198430  2010-01-31                abilenetaylortx
# 2198431  2010-01-31              abingdonharfordmd
# 2198432  2010-01-31                 abingdonknoxil
# ...

# %%
d2.head()
# Out:
#                Date            RegionName  MedianSoldPricePerSqft_AllHomes  \
# 2198416  2010-01-31  abbevilleabbevillesc                              NaN
# 2198417  2010-01-31      abbevillehenryal                              NaN
# 2198418  2010-01-31  abbevillelafayettems                              NaN
# 2198419  2010-01-31  abbevillevermilionla                              NaN
# 2198420  2010-01-31    abbottstownadamspa                              NaN
#
#          MedianRentalPrice_AllHomes
# 2198416                         NaN
# 2198417                         NaN
# 2198418                         NaN
# 2198419                         NaN
# 2198420                         NaN

# %%
d2[["MedianSoldPricePerSqft_AllHomes", "MedianRentalPrice_AllHomes"]].plot()
# Set x and y limits
#plt.xlim(-1,len(x_values))
plt.ylim(0,1000)
# Out:
# (0, 1000)

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd

data = [go.Scatter(x=d2.Date,y=d2['MedianSoldPricePerSqft_AllHomes'])]

py.iplot(data)
# Out:
# C:\Users\pkodak\Anaconda3\lib\site-packages\plotly\plotly\plotly.py:224: UserWarning:
#
# Woah there! Look at all those points! Due to browser limitations, the Plotly SVG drawing functions have a hard time graphing more than 500k data points for line charts, or 40k points for other types of charts. Here are some suggestions:
# (1) Use the `plotly.graph_objs.Scattergl` trace object to generate a WebGl graph.
# (2) Trying using the image API to return an image instead of a graph URL
# (3) Use matplotlib
# (4) See if you can create your visualization with fewer data points
#
# If the visualization you're using aggregates points (e.g., box plot, histogram, etc.) you can disregard this warning.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-1ad4eb7fe428> in <module>()
#       6 data = [go.Scatter(x=d2.Date,y=d2['MedianSoldPricePerSqft_AllHomes'])]
#       7
# ...

# %%
#get citicrosswalk data
cityc= pd.read_csv('C:\\Pri doc\\priti\\Projects\\Myproject\\Berkely\\My class projects data\\zecon\\cities_crosswalk.csv')

# %%
#Get data for specific state 
cmask1 = cityc["State"] == 'CA'
cmask2 = cityc["County"] == 'San Mateo'

# %%
cityc[cmask1 & cmask2]
# Out:
#                           Unique_City_ID                    City     County  \
# 174         broadmoor_villagesan_mateoca       Broadmoor Village  San Mateo
# 331       south_san_franciscosan_mateoca     South San Francisco  San Mateo
# 2110                san_brunosan_mateoca               San Bruno  San Mateo
# 3599                  montarasan_mateoca                 Montara  San Mateo
# 5260              foster_citysan_mateoca             Foster City  San Mateo
# 6074               moss_beachsan_mateoca              Moss Beach  San Mateo
# 6186                san_mateosan_mateoca               San Mateo  San Mateo
# 6297                 woodsidesan_mateoca                Woodside  San Mateo
# 6328   highlands_baywood_parksan_mateoca  Highlands-Baywood Park  San Mateo
# 8494             san_gregoriosan_mateoca            San Gregorio  San Mateo
# 9421                pescaderosan_mateoca               Pescadero  San Mateo
# ...

# %%
citylist = cityc[cmask1 & cmask2].Unique_City_ID
mycitylist =
# Out:
# 174           broadmoor_villagesan_mateoca
# 331         south_san_franciscosan_mateoca
# 2110                  san_brunosan_mateoca
# 3599                    montarasan_mateoca
# 5260                foster_citysan_mateoca
# 6074                 moss_beachsan_mateoca
# 6186                  san_mateosan_mateoca
# 6297                   woodsidesan_mateoca
# 6328     highlands_baywood_parksan_mateoca
# 8494               san_gregoriosan_mateoca
# 9421                  pescaderosan_mateoca
# 10952            east_palo_altosan_mateoca
# 11010              redwood_citysan_mateoca
# 12499                   belmontsan_mateoca
# 15205                menlo_parksan_mateoca
# 15495            portola_valleysan_mateoca
# 17282                san_carlossan_mateoca
# 17648           north_fair_oakssan_mateoca
# 18143                  pacificasan_mateoca
# 18640                burlingamesan_mateoca
# 19164                  millbraesan_mateoca
# 21379              hillsboroughsan_mateoca
# ...

# %%
d2.head()
# Out:
#                Date            RegionName  MedianSoldPricePerSqft_AllHomes  \
# 2198416  2010-01-31  abbevilleabbevillesc                              NaN
# 2198417  2010-01-31      abbevillehenryal                              NaN
# 2198418  2010-01-31  abbevillelafayettems                              NaN
# 2198419  2010-01-31  abbevillevermilionla                              NaN
# 2198420  2010-01-31    abbottstownadamspa                              NaN
#
#          MedianRentalPrice_AllHomes
# 2198416                         NaN
# 2198417                         NaN
# 2198418                         NaN
# 2198419                         NaN
# 2198420                         NaN

# %%
df1[df1["RegionName"] == 'east_palo_altosan_mateoca']
# Out:
#                Date                 RegionName  \
# 2339     1996-04-30  east_palo_altosan_mateoca
# 12256    1996-05-31  east_palo_altosan_mateoca
# 22296    1996-06-30  east_palo_altosan_mateoca
# 32390    1996-07-31  east_palo_altosan_mateoca
# 42485    1996-08-31  east_palo_altosan_mateoca
# 52588    1996-09-30  east_palo_altosan_mateoca
# 62668    1996-10-31  east_palo_altosan_mateoca
# 72756    1996-11-30  east_palo_altosan_mateoca
# 82833    1996-12-31  east_palo_altosan_mateoca
# 92938    1997-01-31  east_palo_altosan_mateoca
# 103203   1997-02-28  east_palo_altosan_mateoca
# 113826   1997-03-31  east_palo_altosan_mateoca
# 124513   1997-04-30  east_palo_altosan_mateoca
# 135236   1997-05-31  east_palo_altosan_mateoca
# 145977   1997-06-30  east_palo_altosan_mateoca
# 156718   1997-07-31  east_palo_altosan_mateoca
# 167501   1997-08-31  east_palo_altosan_mateoca
# 178371   1997-09-30  east_palo_altosan_mateoca
# 189235   1997-10-31  east_palo_altosan_mateoca
# ...
